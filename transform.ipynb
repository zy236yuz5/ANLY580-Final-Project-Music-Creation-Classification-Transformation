# %%
import random
import librosa
import numpy as np
import soundfile as sf




def add_white_noise(signal, noise_percentage_factor):
    noise = np.random.normal(0, signal.std(), signal.size)
    augmented_signal = signal + noise * noise_percentage_factor
    return augmented_signal


def time_stretch(signal, time_stretch_rate):
    """Time stretching implemented with librosa References:
    https://librosa.org/doc/main/generated/librosa.effects.pitch_shift.html?highlight=pitch%20shift#librosa.effects.pitch_shift
    """
    return librosa.effects.time_stretch(signal, time_stretch_rate)


def pitch_scale(signal, sr, num_semitones):
    """Pitch scaling implemented with librosa References:
    https://librosa.org/doc/main/generated/librosa.effects.pitch_shift.html?highlight=pitch%20shift#librosa.effects.pitch_shift
    """
    return librosa.effects.pitch_shift(signal, sr, num_semitones)


def random_gain(signal, min_factor=0.1, max_factor=0.12):
    gain_rate = random.uniform(min_factor, max_factor)
    augmented_signal = signal * gain_rate * 10000000 * -1
    return augmented_signal


def invert_polarity(signal):
    return signal * -1


if __name__ == "__main__":
    signal, sr = librosa.load("./Inputs_/Created_inputs/gpt-15.wav")    # Fill in the input music
    augmented_signal1 = invert_polarity(signal)
    augmented_signal2 = random_gain(signal)
    augmented_signal3 = pitch_scale(signal, sr, 4)
    augmented_signal4 = time_stretch(signal, 0.2)
    augmented_signal5 = add_white_noise(signal, 0.5)
    sf.write("augmented_audio1.wav", augmented_signal1, sr)
    sf.write("augmented_audio2.wav", augmented_signal2, sr)  # THIS IS THE WHITE NOISE, NOT PLEASANT!
    sf.write("augmented_audio3.wav", augmented_signal3, sr)
    sf.write("augmented_audio4.wav", augmented_signal4, sr)
    sf.write("augmented_audio5.wav", augmented_signal5, sr)

    combined = time_stretch(pitch_scale(augmented_signal3, sr, 7), 1.2)
    sf.write("combined_audio.wav", combined , sr)
# Out:
# C:\Users\yzh20\AppData\Local\Temp\ipykernel_25124\2524963371.py:26: FutureWarning: Pass sr=22050, n_steps=4 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.pitch_shift(signal, sr, num_semitones)
# C:\Users\yzh20\AppData\Local\Temp\ipykernel_25124\2524963371.py:19: FutureWarning: Pass rate=0.2 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(signal, time_stretch_rate)
# C:\Users\yzh20\AppData\Local\Temp\ipykernel_25124\2524963371.py:26: FutureWarning: Pass sr=22050, n_steps=7 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.pitch_shift(signal, sr, num_semitones)
# ...

# %%
audio1 = 'augmented_audio1.wav'
x1, p1 = librosa.load(audio1)

# %%
x1 , p1
# Out:
# (array([-3.0517578e-05,  3.0517578e-05, -6.1035156e-05, ...,
#         -3.0517578e-05, -5.4931641e-04,  0.0000000e+00], dtype=float32),
#  22050)

# %%
audio2 = 'augmented_audio2.wav'
x2, p2 = librosa.load(audio2)

audio3 = 'augmented_audio3.wav'
x3, p3 = librosa.load(audio3)

audio4 = 'augmented_audio4.wav'
x4, p4 = librosa.load(audio4)

audio5 = 'augmented_audio5.wav'
x5, p5 = librosa.load(audio5)

# %%
x2, p2
# Out:
# (array([-1.       ,  0.9999695, -1.       , ..., -1.       , -1.       ,
#          0.       ], dtype=float32),
#  22050)

# %%
x3, p3
# Out:
# (array([-3.0517578e-05, -3.0517578e-05,  3.0517578e-05, ...,
#          9.1552734e-05,  1.8310547e-04,  0.0000000e+00], dtype=float32),
#  22050)

# %%
x5
# Out:
# array([ 0.1515503 , -0.13674927, -0.0642395 , ..., -0.01950073,
#         0.03518677, -0.18960571], dtype=float32)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display 

plt.figure(figsize = (14, 8))
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Soundwaves of the original created")
librosa.display.waveshow(x1[0:100], sr=p1)

# %%
plt.figure(figsize = (14, 8))
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Soundwaves of the original created")
librosa.display.waveshow(x2[0:100], sr=p2)

# %%
plt.figure(figsize = (14, 8))
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Soundwaves of the original created")
librosa.display.waveshow(x3[0:100], sr=p3)

# %%
plt.figure(figsize = (14, 8))
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Soundwaves of the original created")
librosa.display.waveshow(x4[0:100], sr=p4)

# %%
plt.figure(figsize = (14, 8))
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Soundwaves of the original created")
librosa.display.waveshow(x5[0:100], sr=p5)
