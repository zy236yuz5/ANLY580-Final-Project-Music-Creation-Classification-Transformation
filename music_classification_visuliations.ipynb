# %%
import librosa

# %%
audio = './inputs_/Created_inputs/gpt-5.wav'
x, p = librosa.load(audio)

# %%
audio6 = './inputs_/Created_inputs/gpt-15.wav'
x6, p6 = librosa.load(audio6)

# %%
print(type(x), type(p))
print(x.shape, p)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (1549013,) 22050

# %%
librosa.load(audio, sr = 44100)
# Out:
# (array([ 3.6537722e-06, -3.3043823e-05, -3.9155057e-05, ...,
#          2.1875336e-05,  3.5319328e-05, -1.7706094e-05], dtype=float32),
#  44100)

# %%
import IPython.display as ipd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display 

# The sound waves
plt.figure(figsize = (14, 8))
plt.rcParams.update({'font.size': 22})
librosa.display.waveshow(x, sr=p)
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Sound Wave of the music generated")
# Out:
# Text(0.5, 1.0, 'The Sound Wave of the music generated')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display 

plt.figure(figsize = (14, 8))
plt.rcParams.update({'font.size': 22})
librosa.display.waveshow(x6, sr=p6)
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Sound Wave of the music generated")
# Out:
# Text(0.5, 1.0, 'The Sound Wave of the music generated')

# %% [markdown]
# Spectrogram
# A spectrogram is a visual representation of the spectrum of frequencies of sound or other signals as they vary with time. Spectrograms are sometimes called sonographs, voiceprints, or voicegrams. When the data is represented in a 3D plot, they may be called waterfalls. In 2-dimensional arrays, the first axis is frequency while the second axis is time.
#
# We can display a spectrogram using. librosa.display.specshow.

# %%
Spec = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(Spec))
plt.figure(figsize = (14,8))
plt.rcParams.update({'font.size': 22})
librosa.display.specshow(Xdb, sr=p, x_axis = 'time', y_axis = 'hz')
plt.colorbar()

plt.title("The Spectrogram of the music generated")
# Out:
# Text(0.5, 1.0, 'The Spectrogram of the music generated')

# %%
plt.figure(figsize = (14,8))
plt.rcParams.update({'font.size': 22})
librosa.display.specshow(Xdb, sr = p, x_axis = 'time', y_axis='log')

plt.colorbar()
plt.title("The Log Spectrogram of the music generated")
# Out:
# Text(0.5, 1.0, 'The Log Spectrogram of the music generated')

# %%
import soundfile as sf
sf.write('stereo_file1.wav',  x, p)

# %%
n0 = 9000
n1 = 9100
plt.figure(figsize = (14,8))
plt.rcParams.update({'font.size': 22})
plt.plot(x[0:100])
plt.grid()
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Note frequency of the music generated")
# Out:
# Text(0.5, 1.0, 'The Note frequency of the music generated')

# %%
n0 = 9000
n1 = 9100
plt.figure(figsize = (14,8))
plt.rcParams.update({'font.size': 22})
plt.plot(x6[100:200])
plt.grid()
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Note frequency of the music generated")
# Out:
# Text(0.5, 1.0, 'The Note frequency of the music generated')

# %%
zero_crossings = librosa.zero_crossings(x[n0:n1], pad=False)
print(sum(zero_crossings))
# Out:
# 54

# %%
# So spectral centroid for blues song will lie somewhere near the middle of its spectrum while that for a metal song would be towards its end.

# librosa.feature.spectral_centroid computes the spectral centroid for each frame in a signal:

# %%
center = librosa.feature.spectral_centroid(x, sr= p)[0]
center.shape
# Out:
# C:\Users\yzh20\AppData\Local\Temp\ipykernel_11392\2690203248.py:1: FutureWarning: Pass y=[ 3.6537722e-06 -3.9155057e-05  3.8709692e-05 ... -4.8947072e-04
#   2.1875336e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   center = librosa.feature.spectral_centroid(x, sr= p)[0]
# (3026,)

# %%
# Time variable for visualization
frames = range(len(center))
t = librosa.frames_to_time(frames)

# %%
import sklearn.preprocessing
def normalize(x, axis = 0):
    return sklearn.preprocessing.minmax_scale(x, axis = axis)

# %%
style1 = 'jazz.wav'
x1, p1 = librosa.load(style1)

# %%
style1 = 'jazz.wav'
x1, p1 = librosa.load(style1)

# %%
style2 = 'metal.wav'
x2, p2 = librosa.load(style2)

# %%
style3 = 'rock.wav'
x3, p3 = librosa.load(style3)

# %%
center1 = librosa.feature.spectral_centroid(x1, sr= p1)[0]
center1.shape
# Out:
# C:\Users\yzh20\AppData\Local\Temp\ipykernel_11392\937400251.py:1: FutureWarning: Pass y=[-0.00924683 -0.01177979 -0.01370239 ...  0.0071106   0.00561523
#   0.00561523] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   center1 = librosa.feature.spectral_centroid(x1, sr= p1)[0]
# (1293,)

# %%
center2 = librosa.feature.spectral_centroid(x2, sr= p2)[0]
center2.shape
# Out:
# C:\Users\yzh20\AppData\Local\Temp\ipykernel_11392\1606960267.py:1: FutureWarning: Pass y=[-0.12237549 -0.04919434  0.04440308 ... -0.17837524 -0.08401489
#  -0.0284729 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   center2 = librosa.feature.spectral_centroid(x2, sr= p2)[0]
# (1293,)

# %%
center3 = librosa.feature.spectral_centroid(x3, sr= p3)[0]
center3.shape
# Out:
# C:\Users\yzh20\AppData\Local\Temp\ipykernel_11392\887483463.py:1: FutureWarning: Pass y=[-0.01702881 -0.02908325 -0.02832031 ...  0.41622925  0.43777466
#   0.41693115] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   center3 = librosa.feature.spectral_centroid(x3, sr= p3)[0]
# (1293,)

# %%
#Centroid along the waveform
plt.figure(figsize = (14,8))
plt.rcParams.update({'font.size': 22})
plt.plot(x1[0:31])
plt.grid()
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Jazz Sound Wave center line and music generated ")
librosa.display.waveshow(x1, sr=p1, alpha = 0.4)
plt.plot(t, normalize(center), color = 'r')

# %%
#Centroid along the waveform
plt.figure(figsize = (14,8))
plt.rcParams.update({'font.size': 22})
plt.plot(x3[0:31])
plt.grid()
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Rock Sound Wave center line and music generated ")
librosa.display.waveshow(x3, sr=p3, alpha = 0.4)
plt.plot(t, normalize(center), color = 'r')

# %%
#Centroid along the waveform
plt.figure(figsize = (14,8))
plt.rcParams.update({'font.size': 22})
plt.plot(x2[0:31])
plt.grid()
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Metal Sound Wave center line and music generated ")
librosa.display.waveshow(x2, sr=p2, alpha = 0.4)
plt.plot(t, normalize(center), color = 'r')

# %%
rolloff = librosa.feature.spectral_rolloff(x + 0.01, sr=p)[0]
plt.figure(figsize = (14,8))
plt.rcParams.update({'font.size': 22})

plt.grid()
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.title("The Sound Wave of the music generated")
librosa.display.waveshow(x, sr=p, alpha = 0.4)
plt.plot(t, normalize(rolloff), color = 'r')
# Out:
# C:\Users\yzh20\AppData\Local\Temp\ipykernel_11392\2209470206.py:1: FutureWarning: Pass y=[0.01000365 0.00996085 0.01003871 ... 0.00951053 0.01002187 0.01      ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = librosa.feature.spectral_rolloff(x + 0.01, sr=p)[0]

# %%
# Create signal
import numpy as np

# %%
sr = 22050
t = 5
t_ = np.linspace(0, t, int(t*sr), endpoint=False)
x = 0.5*np.sin(2*np.pi*220*t_)

# %%
sf.write('t.wav',  x, sr)
